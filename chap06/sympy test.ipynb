# %%
from sympy import expand, factor, symbols

# %%
x, y ,z = symbols('x y z')

# %%
factor(1-4*z**-1+6.4*z**-2-5.12*z**-3+2.048*z**-4-0.32768*z**-5)
# Out:
# 6.4*(0.15625*z**5 - 0.625*z**4 + 1.0*z**3 - 0.8*z**2 + 0.32*z - 0.0512)/z**5

# %%
factor(x**2 + 0.3*x+0.02)
# Out:
# 1.0*(1.0*x + 0.1)*(1.0*x + 0.2)

# %%
factor(1 + 16.0625*z**-4 + z**-8)
# Out:
# 16.0*(0.0625*z**4 + 1.0)*(1.0*z**4 + 0.0625)/z**8

# %%
factor(z**8*(1 + 16.0625*z**-4 + z**-8))
# Out:
# 16.0*(0.0625*z**4 + 1.0)*(1.0*z**4 + 0.0625)

# %%
test = expand((1-0.8*z**-1)**5)
test
# Out:
# 1 - 4.0/z + 6.4/z**2 - 5.12/z**3 + 2.048/z**4 - 0.32768/z**5

# %%
test.subs(z,1)
# Out:
# 0.000320000000001097
