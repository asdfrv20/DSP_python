# %% [markdown]
# # chap03_ex09

# %% [markdown]
# ## import Lib

# %%
import numpy as np
import matplotlib.pylab as plt
from scipy import signal
import nbimporter
from chap03_module import *

# %% [markdown]
# ## 문제 a

# %% [markdown]
# ## 문제 b

# %% [markdown]
# ## 문제 c
