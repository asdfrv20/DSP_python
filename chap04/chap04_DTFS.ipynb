# %% [markdown]
# # chap04_DTFS

# %% [markdown]
# ## import Lib

# %%
import numpy as np
import matplotlib.pylab as plt
import nbimporter
from chap04_module import *

# %% [markdown]
# ## code

# %%
xn = [0,1,2,3]
print("x(n)=",xn)
N = len(xn)
Xk = DTFS(xn, N)
print("X(k)=", Xk)
print("|X(k)|=", np.abs(Xk))

n = np.arange(N)

plt.figure(figsize=(9,6))
plt.subplot(2,1,1); plt.stem(n,xn,'b'); plt.grid()
plt.title("DTFS of a discrete periodic signal x(n)"); plt.ylabel("x(n)")
plt.subplot(2,1,2); plt.stem(n,np.abs(Xk),'g'); plt.grid()
plt.xlabel("k"); plt.ylabel("|X(k)|")
# Out:
# x(n)= [0, 1, 2, 3]
# X(k)= [ 6.+0.0000000e+00j -2.+2.0000000e+00j -2.-7.3478806e-16j
#  -2.-2.0000000e+00j]
# |X(k)|= [6.       2.828427 2.       2.828427]
# Text(0, 0.5, '|X(k)|')
