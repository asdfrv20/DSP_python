# %% [markdown]
# # DFT_IDF_test

# %% [markdown]
# ## import Lib

# %%
import numpy as mp 
import matplotlib.pylab as plt
import nbimporter
from chap04_module import *

# %% [markdown]
# ## code

# %%
# 시퀀스 생성
xn = [1,1,1,1]
N = 4
print('x(n)=', xn)
Xk = DFT(xn,N)
print('Xk=',Xk)

magXk = np.abs(Xk)
print('Magnitude of Xk=',magXk)
phaXk = np.angle(Xk)*180/np.pi
print('Phase of Xk=',phaXk)

xn = np.real(IDFT(Xk,N))
print('Reconstructed xn=',xn)
# Out:
# x(n)= [1, 1, 1, 1]
# Xk= [ 4.0000000e+00+0.0000000e+00j -1.8369701e-16-2.2204460e-16j
#   0.0000000e+00-2.4492937e-16j  3.2904647e-16-3.3306691e-16j]
# Magnitude of Xk= [4.0000000e+00 2.8818120e-16 2.4492937e-16 4.6819349e-16]
# Phase of Xk= [   0.       -129.60089   -90.        -45.347904]
# Reconstructed xn= [1. 1. 1. 1.]
